# %% [markdown]
# <a href="https://colab.research.google.com/github/MangoGrove/MangoGrove.github.io/blob/main/HWK04/HWK_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/aarsri/nlp_hw4.git
# Out:
# Cloning into 'nlp_hw4'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 21 (delta 6), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (21/21), 15.91 KiB | 7.96 MiB/s, done.
# Resolving deltas: 100% (6/6), done.

# %%
import sys

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
class LanguageModel:

    def __init__(self, model_name='gpt2', device=None, mode='greedy', k=None, p=None, temperature=1.0):
        self.tokenizer = AutoTokenizer.from_pretrained(model_name)
        self.model = AutoModelForCausalLM.from_pretrained(model_name)
        self.device = device or ("cuda" if torch.cuda.is_available() else "cpu")
        self.model.to(self.device)

        self.mode = mode
        self.k = k
        self.p = p
        self.temperature = temperature

    def start(self, text):
        """Tokenize input string and return model-ready tensors."""
        inputs = self.tokenizer(text, return_tensors='pt') # adds BOS/EOS by default, returns numberized tokens
        return {k: v.to(self.device) for k, v in inputs.items()}

    def step(self, state):
        """Perform one decoding step given current state."""
        with torch.no_grad():
            outputs = self.model(**state)
            next_token = self.decoding_algorithm(outputs)
            # Append new token to input
            state['input_ids'] = torch.cat([state['input_ids'], next_token.unsqueeze(0)], dim=1)
            state['attention_mask'] = torch.cat(
                [state['attention_mask'], torch.ones((1,1), device=self.device)], dim=1
            )
        return state

    def decoding_algorithm(self, outputs):
        """Choose the next token according to the selected decoding strategy."""

        # TODO: use self.temperature to incorporate temperature sampling

        logits = outputs.logits[:, -1, :]
        logits = logits/self.temperature
        probs = torch.softmax(logits, dim=-1).squeeze(0)

        if self.mode == 'greedy':
            # TODO: apply decoding method to obtain next token
            next_token = torch.argmax(probs)
            next_token = next_token.unsqueeze(0) #torch.tensor([[next_token]])


        elif self.mode == 'sampling':
            # TODO: apply decoding method to obtain next token
            next_token = torch.multinomial(probs, num_samples=1)


        elif self.mode == 'top-k':
            # TODO: apply decoding method to obtain next token
            top_k_probs, top_k_indices = torch.topk(probs, k=self.k)
            next_token = torch.multinomial(top_k_probs, num_samples=1)
            next_token = torch.gather(top_k_indices, 0, next_token)
            #next_token = torch.unsqueeze(next_token, 0)

        elif self.mode == 'top-p':
            # TODO: apply decoding method to obtain next token
            sorted_probs, sorted_indices = torch.sort(probs, descending=True)
            cumulative_probs = torch.cumsum(sorted_probs, dim=-1)

            indices_to_remove = cumulative_probs > self.p
            # Ensure at least one token is kept
            indices_to_remove[..., 0] = False

            sorted_probs[indices_to_remove] = 0.0
            # Renormalize the probabilities if some were set to zero
            sorted_probs = sorted_probs / sorted_probs.sum() if sorted_probs.sum() > 0 else sorted_probs

            sampled_idx_in_sorted = torch.multinomial(sorted_probs, num_samples=1)
            next_token = sorted_indices[sampled_idx_in_sorted] # Ensures shape [1]


        return next_token

    # The `generate()` method below is NOT HuggingFace's built-in `.generate()`.
    # It simply runs our custom decoding loop using your implementation of greedy search, sampling, top-k, and top-p.
    # You may NOT use `model.generate()` from the HuggingFace Transformers library.
    def generate(self, prompt, max_new_tokens=40):
        """Generate a continuation from a given prompt."""
        state = self.start(prompt)
        for _ in range(max_new_tokens):
            state = self.step(state)
        output_ids = state['input_ids'].squeeze().tolist()
        return self.tokenizer.decode(output_ids, skip_special_tokens=True)

# %%
if __name__ == '__main__':
    with open('/content/nlp_hw4/storycloze-2018/short_context_data.txt') as f:
        contexts = [line.strip() for line in f if line.strip()]
        print(contexts)
    # TODO: run the model with different decoding methods and print the outputs (as outlined in the assignment)
    #Rows are temperature x k combinations (9 total rows),
    #columns are features, cells are filled with checks if the feature is present.
    lm = LanguageModel(mode='greedy')
    print(len(contexts))

    #temperatures = [0.2, 0.8, 1]
    #top_ks = [10, 40, 100]
    #results = []

    print("top k decoding")
    n = 1
    #for temperature in temperatures:
    #    for top_k in top_ks:
    top_k = 40
    lm = LanguageModel(mode='top-k', k=top_k) #, temperature=temperature)
    #all = []
    print(f"Top-k: {top_k}")
    for begining in contexts[:40]:
      output = lm.generate(begining, max_new_tokens=40)
      #all.append(output)
      print(f"{n}.  Context: {begining}\n→ {output}\n")
      n += 1
            #results.append({'temperature': temperature, 'top_k': top_k, 'outputs': all})
            #results.append(lm.generate(contexts[0]))
            #print(results)
            #print(lm.generate(contexts[0]))

    print("top p decoding")
    n = 0
    ps =  0.9
    lm = LanguageModel(mode='top-p', p=ps)
    for begining in contexts[:40]:
      output = lm.generate(begining, max_new_tokens=40)
      print(f"{n}.  Context: {begining}\n→ {output}\n")
      n += 1


    #for begining in contexts:
    #  lm.generate(begining)
# Out:
# ['Rick grew up in a troubled household.', "Laverne needs to prepare something for her friend's party.", 'Sarah had been dreaming of visiting Europe for years.', 'Gina was worried the cookie dough in the tube would be gross.', 'It was  my final performance in marching band.', 'Jim found an old disposable camera in the bottom of his junk drawer.', 'Ron started his new job as a landscaper today.', 'John and Billy became very skilled at beer pong.', 'Caroline was a student in medical school.', 'Trish hated the outdoors.', 'Tony was happy to be going on his first cruise.', 'Ignacio wants to play a sport while he is in college.', 'Danny bought a boat.', 'At school, Mary received an assignment to write an essay about pandas.', 'Ellen dreamed of winning a prize for her roses.', 'Jesse had just started fifth grade.', 'Tiffany was getting overwhelmed at work.', 'Gina misplaced her phone at her grandparents.', 'Alice was getting married in a few weeks.', 'Ted loves to go to the movies.', 'Nya had been asked on a paintball trip with friends.', "All of Javier's friends at school have smartphones.", 'Rachel decided to donate blood at the local blood drive.', 'Ron was watching a high-speed chase on TV.', 'Sam loved his old belt.', 'Larry bought a new motorcycle.', 'I went on a blind date a few days ago.', "Sammy's coffee grinder was broken.", 'Last week Jared was driving to work.', 'Joe grew a big batch of peas in his garden.', 'Aliza had a long lost ex-boyfriend she was bound to find.', 'Lina went to see how candy canes were made.', "When I first moved into my house, I didn't know my neighbors.", 'Bev had been studying very hard.', "We went to Frank Pepe's pizza shop three weeks ago.", 'Bernice always wanted to travel to Africa.', 'Jim made spinach cookies.', "Randy's friend gave him directions to his house.", 'I decided to go on a bike ride with my brother.', 'Anna went to the salon.', 'David and Sarah were friends during childhood.', 'AJ and his mom were at the grocery store.', 'Joe went to the junkyard to find treasures.', 'Priya decided to try a new restaurant.', 'Karen was assigned a roommate her first year of college.', 'We took a family vacation to the beach last year.', 'Donald was kind of the class clown.', "Eddie and Angela hadn't been talking to each other for a long time.", 'Rachel adopted a cat over ten Years ago.', 'Jim is a new driver and has never been pulled over before.', 'I love avocados.', 'David was an author that had trouble finding inspiration for his work.', 'Boris was addicted to video games.', 'A police officer came down with the flu today.', 'My friend nathan and his family went to the lake one summer.', 'Gary was a brave child.', 'Timmy was caught with unpaid parking tickets.', 'When I was younger, I went to summer camp.', 'Amber had a lot of things to do this Sunday.', 'Eve needed a new couch in her parlor.', 'Jason was terrified of spiders.', 'Linda began to have problems with a coworker at her job.', 'Sara wanted her kids to have a great Christmas.', 'Megan has been struggling with a drug habit for years.', 'Tyler has been unemployed for Years.', 'Bobby was having a birthday party.', 'It was the last day of our vacation.', 'Mother asked the children to help fold laundry.', 'Timmy loves watching cartoons.', 'My daughter had her baby shower in our Boston home.', "Pam's house was where the party was.", 'Ellen always hated school.', 'Jim got his first credit card in college.', 'Tim was entering a baking contest.', 'My two year old son refused to wear training pants.', 'Holly was glad to be safely inside her house as the storm raged.', 'Jill saw an infomercial for unbreakable glass cups.', 'Addie was working at the mall at Hollister when a strange man came in.', 'Sean was going for a job interview.', 'Fred made a bet with Sam over who could lose more weight in a month.', 'John went skydiving for the first time.', 'Gina and her family were leaving the park.', 'Kaya needed to buy a new dress for the upcoming Spring F ...
# 100
# top k decoding
# Top-k: 40
# 1.  Context: Rick grew up in a troubled household.
# → Rick grew up in a troubled household. She left for a new job as a reporter for The Dallas Morning News in 1993. She had a family of five and worked with a newspaper staff covering oil and natural gas developments, which helped her in
#
# 2.  Context: Laverne needs to prepare something for her friend's party.
# → Laverne needs to prepare something for her friend's party. He needs to get a little light. That will probably take a lot of time, but maybe the idea works out. And there will also be some chance of him becoming pregnant. He'll need to
#
# 3.  Context: Sarah had been dreaming of visiting Europe for years.
# → Sarah had been dreaming of visiting Europe for years.
#
# Now she was ready.
#
# "You want to be able to leave Paris without being detected? Go to Germany," she replied, looking at the small but familiar man in a paj
#
# 4.  Context: Gina was worried the cookie dough in the tube would be gross.
# → Gina was worried the cookie dough in the tube would be gross. She had never felt so gross after watching The Lord Of The Rings. She even cried on the first day she had been on the set.
#
# "No, not the whole family, that's
#
# 5.  Context: It was  my final performance in marching band.
# → It was  my final performance in marching band. So I am sad that I am able to leave this great family behind. So far I feel this as well because I have been an inspiration for the next five years. I am also very proud of
#
# 6.  Context: Jim found an old disposable camera in the bottom of his junk drawer.
# → Jim found an old disposable camera in the bottom of his junk drawer. No, it wasn't old camera - it was an unused and damaged camera. So what had this stuff been taken? Apparently, some small part of the old camera actually contained the lens at the
#
# 7.  Context: Ron started his new job as a landscaper today.
# → Ron started his new job as a landscaper today.
#
# "I was kind of wondering if there's anything in these photos, but I'm really curious why there's a woman's face when she comes to the window," he told the New York
#
# 8.  Context: John and Billy became very skilled at beer pong.
# → John and Billy became very skilled at beer pong. "When we were brewing we got bored playing with beer pong balls," says Mr. Billy. "So, we went to a show with friends. But it was only 10. So we had
#
# 9.  Context: Caroline was a student in medical school.
# → Caroline was a student in medical school. She had previously been enrolled at a private medical facility, and she was interested in participating in any kind of therapy. She said the therapist was so helpful, they put her in a room with a nurse
#
# 10.  Context: Trish hated the outdoors.
# → Trish hated the outdoors. She had seen that the wind knocked the tree around, and it hit her as she stepped away from the bush. Suddenly the leaves began to twist, and she fell out of the tree. The pain
#
# 11.  Context: Tony was happy to be going on his first cruise.
# → Tony was happy to be going on his first cruise.
#
# "You know, at first we thought, 'Well this isn't going to work,'" he said. "But then you get the people on and they're like -'Oh my god
#
# 12.  Context: Ignacio wants to play a sport while he is in college.
# → Ignacio wants to play a sport while he is in college.
#
# "[Travis] was not interested in the NFL," he said.
#
# Travis hopes the Steelers will "help him be a better player."
#
# This is part of a broader
#
# 13.  Context: Danny bought a boat.
# → Danny bought a boat. He got them by the hand and they came with him.
# → Last week Jared was driving to work. When all was said and done, he'd get a call from a friend at the airport. According to law enforcement sources he had told them he wanted to go to work there.
#
# The same
#
# 30.  Context: Joe grew a big batch of peas in his garden.
# → Joe grew a big batch of peas in his garden. While I was there, I gave him about half-a pound of peas. When the guy was ready, he took a few. After waiting about five or six, he started doing it.
#
#
#
# 31.  Context: Aliza had a long lost ex-boyfriend she was bound to find.
# → Aliza had a long lost ex-boyfriend she was bound to find. In his absence, she would find a mentor and her own unique perspective on life and what it would take to get her back in her former life, the one she wanted to have. This is the
#
# 32.  Context: Lina went to see how candy canes were made.
# → Lina went to see how candy canes were made.
#
# The chocolate is the result of being made in a factory at a different place from the one that made it. The chocolate comes from the "Bambino" family of Italian chocolate, which
#
# 33.  Context: When I first moved into my house, I didn't know my neighbors.
# → When I first moved into my house, I didn't know my neighbors. They were not in schools. And then the first thing the house smelled like... it smelled like sulfur," Phelanen said.
#
# "I don't know if this smells like something that
#
# 34.  Context: Bev had been studying very hard.
# → Bev had been studying very hard. He was at the beginning of it."
#
# But it wasn't only that he had been so keen to study for this year's Winter Olympics.
#
# "I just thought it would be good
#
# 35.  Context: We went to Frank Pepe's pizza shop three weeks ago.
# → We went to Frank Pepe's pizza shop three weeks ago. He always came in, and it was a huge surprise to see this. And I'm just glad there is no more to go on at that location. That's a pretty cool place!
#
#
#
# 36.  Context: Bernice always wanted to travel to Africa.
# → Bernice always wanted to travel to Africa. After her departure she returned two days later, with a big suitcase and a few bags, to join her husband in Tanzania. And on her way to her home town of Togo, she was attacked
#
# 37.  Context: Jim made spinach cookies.
# → Jim made spinach cookies. We had some lemon slices and a few slices of black olives in the freezer - as we left, I wondered if they could be added as well.
#
# The next morning we went with a
#
# 38.  Context: Randy's friend gave him directions to his house.
# → Randy's friend gave him directions to his house. When Candy returned, he met the other men who'd been in the car, got off before Candy turned around to catch up with them and went to their house. Candy followed him and took Candy into
#
# 39.  Context: I decided to go on a bike ride with my brother.
# → I decided to go on a bike ride with my brother. We bought what we needed at a bar called "Old Hops," so we had to make a reservation for a ride to the shop. We wanted to pick up a copy of a book called "
#
# 40.  Context: Anna went to the salon.
# → Anna went to the salon.
#
# "What is it you're doing, sir? Did you just pick me up there?"
#
# "No I had to stay at my place for my mother's funeral. That's fine
#
# top p decoding
# 0.  Context: Rick grew up in a troubled household.
# → Rick grew up in a troubled household. His mother, uncle, and aunt were both drug addicts and he recalled one of the relatives of an addicted infant in his mother's care as telling him to "go to work."
#
# Instead,
#
# 1.  Context: Laverne needs to prepare something for her friend's party.
# → Laverne needs to prepare something for her friend's party.
#
# While being an average baby, Aubrey is instantly thrown in with the adults. When she's not around looking for a body, it is when she is often caught being too freaked out
#
# 2.  Context: Sarah had been dreaming of visiting Europe for years.
# → Sarah had been dreaming of visiting Europe for years.
#
# He dropped her off at a country home in Gibraltar when he and his wife and three children moved in.
#
# He moved back to Britain in 2011, with his wife still living in Glasgow
#
# 3.  Context: Gina was worried the cookie dough in the tube would be gross.
# → Gina was worried the cookie dough in the tube would be gross. But she said she didn't want to give the idea to her daughter.
#
# "My daughter wouldn't eat them," said Mason High School student C.L. Peterson.
#
# Still,
#
# 4.  Context: It was  my final performance in marching band.
# → It was  my final performance in marching band. "" Yet as I rolled down the streets of NYC during the forty-third session, my allegiance to the forces that have helped me through these three years resonated strongly with this high spirited singer.
#
# 5.  Context: Jim found an old disposable camera in the bottom of his junk drawer.
# → Jim found an old disposable camera in the bottom of his junk drawer
#
# 37.  Context: Randy's friend gave him directions to his house.
# → Randy's friend gave him directions to his house. He said he saw he'd been building a house, that all the lighting was going to be going off. And Randy was taking his money.
#
# "I watched him come here and do his
#
# 38.  Context: I decided to go on a bike ride with my brother.
# → I decided to go on a bike ride with my brother. I noticed this feeling in his body, but after a couple of minutes I stopped and just took a look.
#
# We got out of the house and came to the front door. To our surprise
#
# 39.  Context: Anna went to the salon.
# → Anna went to the salon.
#
# "Where are the people?"
#
# "Scout."
#
# "Do you want to come too?"
#
# "Are you sure?"
#
# "I don't want to look

# %% [markdown]
# #Discuss how the outputs from top-k decoding differ from those obtained from greedy search and ancestral sampling. Explicitly tie your explanation to how top-k decoding works in contrast to greedy search and ancestral sampling. Is top-k decoding ever the same as greedy search?
#
#
#
# ---
#
#
# Okay back to the base needs: at least it prints something AND it doesn't repeat like greedy does! Not only that it seeems to be more cohesive with the starting sentence than ancestral sampling is. However it doesn't do a good job in implying/sticking with a gender (though who knows, maybe there is a girl name Rick and I am just allowing my own bias influence my judgement). In that regard the most probabale tokens have helped a lot in structuing the story, however there are odd ones mixed in. That is to say even if it is cohesive it does get more random and at times doesn't quite fit with the prompt. Such as with the first prompt with Rick.
#
# Such as → Laverne needs to prepare something for her friend's party. He needs to get a little light. That will probably take a lot of time, but maybe the idea works out. And there will also be some chance of him becoming pregnant. He'll need to
#
#
# Idea aroung Top-K Decoding: Keep only the k most probable tokens, then sample from them. (k is a hyperparameter)

# %% [markdown]
# #Discuss how the outputs from top-p decoding differ from those obtained from the previous methods. Explicitly tie your explanation to how top-p decoding works in contrast to the other methods, particularly top-k.
#
#
#
# ---
#
# Okay back to the base needs: it also, at least print something and it doesn't repeat like Greedy! Alongside there being a cohesive story that relates more to the given prompt (unline Top-K Decoding where it is somewhat cohesive, but doesn't necessarly relate to the prompt). This prbably has to do with the cumulative probability. Such as Rick now having his troubled past refrence. I will say though that obtaining gender is still a little odd, such as when Sarah is being refrenced.
#
# Order the tokens in descending order of probability.
# Select the smallest number of top tokens such that their cumulative probability is at least p (hyperparameter).
# Sample from only those tokens.

# %% [markdown]
# * greedy sampling

# %%
if __name__ == '__main__':
    with open('/content/nlp_hw4/storycloze-2018/short_context_data.txt') as f:
        contexts = [line.strip() for line in f if line.strip()]
        print(contexts)
    # TODO: run the model with different decoding methods and print the outputs (as outlined in the assignment)
    #Rows are temperature x k combinations (9 total rows),
    #columns are features, cells are filled with checks if the feature is present.
    lm = LanguageModel(mode='greedy')
    print(len(contexts))

    temperatures = [0.2, 0.8, 1]
    top_ks = [10, 40, 100]
    results = []

    lm = LanguageModel(mode='greedy')
    n = 1
    for begining in contexts[:40]:
      output = lm.generate(begining, max_new_tokens=40)

      print(f"{n}.  Context: {begining}\n→ {output}\n")
      n += 1
# Out:
# ['Rick grew up in a troubled household.', "Laverne needs to prepare something for her friend's party.", 'Sarah had been dreaming of visiting Europe for years.', 'Gina was worried the cookie dough in the tube would be gross.', 'It was  my final performance in marching band.', 'Jim found an old disposable camera in the bottom of his junk drawer.', 'Ron started his new job as a landscaper today.', 'John and Billy became very skilled at beer pong.', 'Caroline was a student in medical school.', 'Trish hated the outdoors.', 'Tony was happy to be going on his first cruise.', 'Ignacio wants to play a sport while he is in college.', 'Danny bought a boat.', 'At school, Mary received an assignment to write an essay about pandas.', 'Ellen dreamed of winning a prize for her roses.', 'Jesse had just started fifth grade.', 'Tiffany was getting overwhelmed at work.', 'Gina misplaced her phone at her grandparents.', 'Alice was getting married in a few weeks.', 'Ted loves to go to the movies.', 'Nya had been asked on a paintball trip with friends.', "All of Javier's friends at school have smartphones.", 'Rachel decided to donate blood at the local blood drive.', 'Ron was watching a high-speed chase on TV.', 'Sam loved his old belt.', 'Larry bought a new motorcycle.', 'I went on a blind date a few days ago.', "Sammy's coffee grinder was broken.", 'Last week Jared was driving to work.', 'Joe grew a big batch of peas in his garden.', 'Aliza had a long lost ex-boyfriend she was bound to find.', 'Lina went to see how candy canes were made.', "When I first moved into my house, I didn't know my neighbors.", 'Bev had been studying very hard.', "We went to Frank Pepe's pizza shop three weeks ago.", 'Bernice always wanted to travel to Africa.', 'Jim made spinach cookies.', "Randy's friend gave him directions to his house.", 'I decided to go on a bike ride with my brother.', 'Anna went to the salon.', 'David and Sarah were friends during childhood.', 'AJ and his mom were at the grocery store.', 'Joe went to the junkyard to find treasures.', 'Priya decided to try a new restaurant.', 'Karen was assigned a roommate her first year of college.', 'We took a family vacation to the beach last year.', 'Donald was kind of the class clown.', "Eddie and Angela hadn't been talking to each other for a long time.", 'Rachel adopted a cat over ten Years ago.', 'Jim is a new driver and has never been pulled over before.', 'I love avocados.', 'David was an author that had trouble finding inspiration for his work.', 'Boris was addicted to video games.', 'A police officer came down with the flu today.', 'My friend nathan and his family went to the lake one summer.', 'Gary was a brave child.', 'Timmy was caught with unpaid parking tickets.', 'When I was younger, I went to summer camp.', 'Amber had a lot of things to do this Sunday.', 'Eve needed a new couch in her parlor.', 'Jason was terrified of spiders.', 'Linda began to have problems with a coworker at her job.', 'Sara wanted her kids to have a great Christmas.', 'Megan has been struggling with a drug habit for years.', 'Tyler has been unemployed for Years.', 'Bobby was having a birthday party.', 'It was the last day of our vacation.', 'Mother asked the children to help fold laundry.', 'Timmy loves watching cartoons.', 'My daughter had her baby shower in our Boston home.', "Pam's house was where the party was.", 'Ellen always hated school.', 'Jim got his first credit card in college.', 'Tim was entering a baking contest.', 'My two year old son refused to wear training pants.', 'Holly was glad to be safely inside her house as the storm raged.', 'Jill saw an infomercial for unbreakable glass cups.', 'Addie was working at the mall at Hollister when a strange man came in.', 'Sean was going for a job interview.', 'Fred made a bet with Sam over who could lose more weight in a month.', 'John went skydiving for the first time.', 'Gina and her family were leaving the park.', 'Kaya needed to buy a new dress for the upcoming Spring F ...
# 100
# 1.  Context: Rick grew up in a troubled household.
# → Rick grew up in a troubled household. He was a high school dropout, and he was a high school dropout. He was a high school dropout. He was a high school dropout. He was a high school dropout
#
# 2.  Context: Laverne needs to prepare something for her friend's party.
# → Laverne needs to prepare something for her friend's party.
#
# "I'm not going to be able to do that," she says. "I'm not going to be able to do that. I'm not going to be able to do that.
#
# 3.  Context: Sarah had been dreaming of visiting Europe for years.
# → Sarah had been dreaming of visiting Europe for
# "I'm going to go to the bathroom," Randy said. "I'm going to go to the bathroom."
#
# Randy said he was going to go to the bathroom.
#
#
# 39.  Context: I decided to go on a bike ride with my brother.
# → I decided to go on a bike ride with my brother. I was so excited to get back to the city. I was so excited to get back to the city. I was so excited to get back to the city. I was so excited to get back
#
# 40.  Context: Anna went to the salon.
# → Anna went to the salon.
#
# "I'm sorry, but I'm not going to be able to do this," she said. "I'm not going to be able to do this."
#
# She said she was

# %% [markdown]
# #Free response: What looks good and bad about the outputs from greedy search, and why? Explicitly tie your explanation to how greedy search works.
#
#
# ---
#
# I think, as just something basic, that it's a good thing that the greedy
# algorithm is producing at least something!  And even makes sence for some of them. However because Greedy is based on the highest probability (with not change afterwards) that leads to the problem of repitation. All of these sentence had some sort of repitition to it (and not re-interation, but straight repitition).

# %% [markdown]
# * ancestral sampling

# %%
if __name__ == '__main__':
    with open('/content/nlp_hw4/storycloze-2018/short_context_data.txt') as f:
        contexts = [line.strip() for line in f if line.strip()]
        print(contexts)
    # TODO: run the model with different decoding methods and print the outputs (as outlined in the assignment)
    #Rows are temperature x k combinations (9 total rows),
    #columns are features, cells are filled with checks if the feature is present.

    lm = LanguageModel(mode='sampling')
    n = 1
    for begining in contexts[:40]:
      output = lm.generate(begining, max_new_tokens=40)

      print(f"{n}.  Context: {begining}\n→ {output}\n")
      n += 1
# Out:
# ['Rick grew up in a troubled household.', "Laverne needs to prepare something for her friend's party.", 'Sarah had been dreaming of visiting Europe for years.', 'Gina was worried the cookie dough in the tube would be gross.', 'It was  my final performance in marching band.', 'Jim found an old disposable camera in the bottom of his junk drawer.', 'Ron started his new job as a landscaper today.', 'John and Billy became very skilled at beer pong.', 'Caroline was a student in medical school.', 'Trish hated the outdoors.', 'Tony was happy to be going on his first cruise.', 'Ignacio wants to play a sport while he is in college.', 'Danny bought a boat.', 'At school, Mary received an assignment to write an essay about pandas.', 'Ellen dreamed of winning a prize for her roses.', 'Jesse had just started fifth grade.', 'Tiffany was getting overwhelmed at work.', 'Gina misplaced her phone at her grandparents.', 'Alice was getting married in a few weeks.', 'Ted loves to go to the movies.', 'Nya had been asked on a paintball trip with friends.', "All of Javier's friends at school have smartphones.", 'Rachel decided to donate blood at the local blood drive.', 'Ron was watching a high-speed chase on TV.', 'Sam loved his old belt.', 'Larry bought a new motorcycle.', 'I went on a blind date a few days ago.', "Sammy's coffee grinder was broken.", 'Last week Jared was driving to work.', 'Joe grew a big batch of peas in his garden.', 'Aliza had a long lost ex-boyfriend she was bound to find.', 'Lina went to see how candy canes were made.', "When I first moved into my house, I didn't know my neighbors.", 'Bev had been studying very hard.', "We went to Frank Pepe's pizza shop three weeks ago.", 'Bernice always wanted to travel to Africa.', 'Jim made spinach cookies.', "Randy's friend gave him directions to his house.", 'I decided to go on a bike ride with my brother.', 'Anna went to the salon.', 'David and Sarah were friends during childhood.', 'AJ and his mom were at the grocery store.', 'Joe went to the junkyard to find treasures.', 'Priya decided to try a new restaurant.', 'Karen was assigned a roommate her first year of college.', 'We took a family vacation to the beach last year.', 'Donald was kind of the class clown.', "Eddie and Angela hadn't been talking to each other for a long time.", 'Rachel adopted a cat over ten Years ago.', 'Jim is a new driver and has never been pulled over before.', 'I love avocados.', 'David was an author that had trouble finding inspiration for his work.', 'Boris was addicted to video games.', 'A police officer came down with the flu today.', 'My friend nathan and his family went to the lake one summer.', 'Gary was a brave child.', 'Timmy was caught with unpaid parking tickets.', 'When I was younger, I went to summer camp.', 'Amber had a lot of things to do this Sunday.', 'Eve needed a new couch in her parlor.', 'Jason was terrified of spiders.', 'Linda began to have problems with a coworker at her job.', 'Sara wanted her kids to have a great Christmas.', 'Megan has been struggling with a drug habit for years.', 'Tyler has been unemployed for Years.', 'Bobby was having a birthday party.', 'It was the last day of our vacation.', 'Mother asked the children to help fold laundry.', 'Timmy loves watching cartoons.', 'My daughter had her baby shower in our Boston home.', "Pam's house was where the party was.", 'Ellen always hated school.', 'Jim got his first credit card in college.', 'Tim was entering a baking contest.', 'My two year old son refused to wear training pants.', 'Holly was glad to be safely inside her house as the storm raged.', 'Jill saw an infomercial for unbreakable glass cups.', 'Addie was working at the mall at Hollister when a strange man came in.', 'Sean was going for a job interview.', 'Fred made a bet with Sam over who could lose more weight in a month.', 'John went skydiving for the first time.', 'Gina and her family were leaving the park.', 'Kaya needed to buy a new dress for the upcoming Spring F ...
# 1.  Context: Rick grew up in a troubled household.
# → Rick grew up in a troubled household. While in middle school he went to L. A.'s church and adopted a jean jacket in the back of the house. He started sharing photos with friends and then came out as gay by the
#
# 2.  Context: Laverne needs to prepare something for her friend's party.
# → Laverne needs to prepare something for her friend's party.
#
# She clears out the city of thieves and lumberjacks working away in Pokecarts, takes out her assistant (the medical tech) all for her own gains, and then it's time
#
# 3.  Context: Sarah had been dreaming of visiting Europe for years.
# → Sarah had been dreaming of visiting Europe for years. She was back in Chinatown again, finalizing plans for yet another Chinese trip through New York, Nairobi and Paris — then, last month she joined Créchede's otherwise post-break
#
# 4.  Context: Gina was worried the cookie dough in the tube would be gross.
# → Gina was worried the cookie dough in the tube would be gross. She bought a loaf of croissant and always imagined having a silky cookie crust. She won't blink though. Gina will love her Sandwich Bon Appetit because she made it.
#
#
# 5.  Context: It was  my final performance in marching band.
# → It was  my final performance in marching band. I loved that band and it was Crazy Me deadstitching to Raymond Harry about the avant-garde ballet, and we all went into dumps.
#
# "Sporting Praxis Extreme
#
# 6.  Context: Jim found an old disposable camera in the bottom of his junk drawer.
# → Jim found an old disposable camera in the bottom of his junk drawer. Somehow, when I put him in front of a computer, I could watch. The photos had blue tape wrapped around them and my hand strokes the tape. A lesson in misadventures!
#
#
#
# 7.  Context: Ron started his new job as a landscaper today.
# → Ron started his new job as a landscaper today. She gets paid ransoms she doesn't get on Facebook for being a "favorite."
#
# Kathy Graziano Quinn looks cute when she works on her lawn. The retired worker rises literally
#
# 8.  Context: John and Billy became very skilled at beer pong.
# → John and Billy became very skilled at beer pong. Billy wants to be a leader in the music industry. Billy wants to buy a Miami club owner to work against him. It is, essentially, a closed-loop game of hide and seek; Billy
#
# 9.  Context: Caroline was a student in medical school.
# → Caroline was a student in medical school.
#
# The group filed suit in 2013 but the jury rejected the case against him and a judge discounted his only previous convictions for developing drug offenses.
#
# A judge in Albany, in Albany, ruled
#
# 10.  Context: Trish hated the outdoors.
# → Trish hated the outdoors. "It's really like performance art since I didn't know what it was dealing with," he said. "But with a long life in Tennessee and traveling back across the border, you like working on
#
# 11.  Context: Tony was happy to be going on his first cruise.
# → Tony was happy to be going on his first cruise. The terminator caller who did NOT want at all to work for him (telepathy)? Sir Philip asking him if he 'real' knows how to talk, Sir Philip had no choice but to return
#
# 12.  Context: Ignacio wants to play a sport while he is in college.
# → Ignacio wants to play a sport while he is in college. Pfeffer believes McLane, another strong prospect, could be in his prime — replacement one Greg Monroe, Barcare Jones, and Wyche won't play.
#
# Rodney is, you
#
# 13.  Context: Danny bought a boat.
# → Danny bought a boat.
#
# The general consensus was that the ship's speed was too low to be of use to pirates. The towed ship immediately sent the troops huddled together to come up with a course to force some
#
# 14.  Context: At school, Mary received an assignment to write an essay about pandas.
# → At school, Mary received an assignment to write an essay about pandas. When she turned 18 on Jan. 1, 1993, James was still very young. Her sister, Kathleen, was pregnant with full-grown pandas by the time she went back in Janata.
#
# 15.  Context: Ellen dreamed of winning a prize for her roses.
# → Ellen dreamed of winning a prize for her roses. One pattern once ran in Spurs shirt:Rachel Trachtenberg of Oakland City is no stranger to pizzeria lunch. From her superstar adventures in Newtown, New York, to something in Francis Ford
#
# 16.  Context: Jesse had just started fifth grade.
# → Jesse had just started fifth grade. On track for passing for more than half a mile and gaining some height, she could hear men yelling from above. It was above him in the distance.
#
# He had slime on his skin.
#
# 17.  Context: Tiffany was getting overwhelmed at work.
# → Tiffany was getting overwhelmed at work. She thought she saw her mother, and at first it sounded like she had tumbled below the waistline. Then she thought it was at an oversized and shackled fetus a few miles away.
#
#
# 18.  Context: Gina misplaced her phone at her grandparents.
# → Gina misplaced her phone at her grandparents.
#
# "It was just moments before I got all used to waking up, I thought I was going out…Things had come full circle…a routine has made me feel like I'm on my
#
# 19.  Context: Alice was getting married in a few weeks.
# → Alice was getting married in a few weeks. Fifteen of his sisters, including Shengfeng, went hungry. When I asked them if they ate on Sunday, they said an average grade of four. I said it doesn't work that
#
# 20.  Context: Ted loves to go to the movies.
# → Ted loves to go to the movies. Mine worked three days a week, going to museums, playing with Martha and Pauline, with Hugh."
#
# Her friends rushed to email her he has been pleased with his treatment. "Anything to
#
# 21.  Context: Nya had been asked on a paintball trip with friends.
# → Nya had been asked on a paintball trip with friends. He had taken his long-distance routes. The split was more annoying than pleasant.
#
# On his way home from Texas to Cannabistoe, his wheel that would have stopped at Montice
#
# 22.  Context: All of Javier's friends at school have smartphones.
# → All of Javier's friends at school have smartphones. He admits to using one at once, but cats can't use a shower.
#
# He is unlucky. He first went to school in public with Monet..... two months ago. He took an
#
# 23.  Context: Rachel decided to donate blood at the local blood drive.
# → Rachel decided to donate blood at the local blood drive. She found 20 bags of blood and collected and analyzed, put them in and carefully packed about 1000 of her Red herring supplements before handing them over to her mother and best friend.
#
# Treatment
#
# 24.  Context: Ron was watching a high-speed chase on TV.
# → Ron was watching a high-speed chase on TV.
#
# Mario rings the bell.
#
# "No, you're not going to kill Claude."
#
# "No,…Derek's down…"
#
# The Jar Benoit whinks for
#
# 25.  Context: Sam loved his old belt.
# → Sam loved his old belt. It was so slim and heavy that he grossly couldn't really handle it as the belt shanked into the air. A kilometer later he'd have half the flycades hidden in a perfect slot
#
# 26.  Context: Larry bought a new motorcycle.
# → Larry bought a new motorcycle. Then, through a legal maneuver and plain ignorance, he began to rob the typical street dealer that saw the clear explanation yet every time problems occur.
#
# Investigators discovered four semi-automatic commitabilty
#
# 27.  Context: I went on a blind date a few days ago.
# → I went on a blind date a few days ago. I just couldn't convince her, so she blurted 'I've done this seven months ago'. She didn't communicate and worse yet, she hated me because I was telling "I have committed adultery
#
# 28.  Context: Sammy's coffee grinder was broken.
# → Sammy's coffee grinder was broken. A hole in the pc caused this problem.
#
# When asked why his intervention went wrong, John Boyden told Jin about his grandfather, Elijah Judah self-employed at a soup kitchen that changed assets
#
# 29.  Context: Last week Jared was driving to work.
# → Last week Jared was driving to work. Still feeling out of his mind, he heard Live From Another Hospital. He wasn't sure what it was. One nurse told him he should go in to this "just in case." He was glad
#
# 30.  Context: Joe grew a big batch of peas in his garden.
# → Joe grew a big batch of peas in his garden. As soon as he noticed that the peas were spoiled and bent into puffy bunts, he brushed them off with a featherlike brush and placed them over the stockage. This shredded the stems of
#
# 31.  Context: Aliza had a long lost ex-boyfriend she was bound to find.
# → Aliza had a long lost ex-boyfriend she was bound to find. Though ever wary of boyfriends and Steve, Seattle was enamored of him. "Yeah, it's like I told him," her daughter Erika stated. This had three links—originally
#
# 32.  Context: Lina went to see how candy canes were made.
# → Lina went to see how candy canes were made. Christina had gone to a creamery to make her chocolate ice cream and was eating an appealing soup with a creamy peanut butter cheesecake a la the monthly London activities gallery mini-gallery Why not try 30
#
# 33.  Context: When I first moved into my house, I didn't know my neighbors.
# → When I first moved into my house, I didn't know my neighbors. I've always been curious about people. It was so natural. It was like real, it was so countless, just for my uniqueness. Every time I are invited to one of these gatherings a different
#
# 34.  Context: Bev had been studying very hard.
# → Bev had been studying very hard. She found it difficult to produce at altitude; much bluntly. When thrown like the hand grenade by agents of Hydra, she was still extreme. For example, Suge Knight lost a face. Clawenh
#
# 35.  Context: We went to Frank Pepe's pizza shop three weeks ago.
# → We went to Frank Pepe's pizza shop three weeks ago. He trades in ghost, all of a sudden I think of this image of sombre mango — some nice "Sweet 270. It's clean and creamy" sort of roseame, just this heart
#
# 36.  Context: Bernice always wanted to travel to Africa.
# → Bernice always wanted to travel to Africa. Just wait until she is basically super whose not she or else she won the contest. Like Madonna said, she is Sarah, we're slaves, there is no practice for her there being a party to
#
# 37.  Context: Jim made spinach cookies.
# → Jim made spinach cookies. :
#
#
# Green beans, diced
#
# Flesenne, chives, ground
#
# Soy sauce, sesame seed presentation
#
# Pepper sauce, seasoned
#
# Honey flavor,
#
# 38.  Context: Randy's friend gave him directions to his house.
# → Randy's friend gave him directions to his house. He'd soon find his way into the forest. The scenario was familiar but it involved notable scenarios (the Death Tree and a fight with the slug swarm being the most common and since there are a couple
#
# 39.  Context: I decided to go on a bike ride with my brother.
# → I decided to go on a bike ride with my brother. It was kind of crazy, but usually [like 5 or 6-year-olds] don't hop on the bike flying down to kids games or school. My dad threw rocks at me for playing
#
# 40.  Context: Anna went to the salon.
# → Anna went to the salon. But there was a class assignment for her and before long, alone. ALesha, no longer feeling safe around her, went in and picked out her dress. She lay on her back and slid

# %% [markdown]
# #Discuss how the outputs from ancestral sampling differ from those obtained from greedy search. Explicitly tie your explanation to how ancestral sampling works in contrast to greedy search
#
#
#
# ---

# %% [markdown]
# Well... as just baseline at least it made something! On top of that it's not repeating like greedy search does! Unfortunately due to weighted nature of the random sampling (one of the aspects that helps it avoid repitition) it ended up creating a non-sensical continuation. Some of them could work, in a way (for example the one about robbing something after getting a bike), but for the most part they jump around with one evenmaking a poem (#37). Ultimately it's main issue is that it doesn't take context into account.

# %%
if __name__ == '__main__':
    with open('/content/nlp_hw4/storycloze-2018/short_context_data.txt') as f:
        contexts = [line.strip() for line in f if line.strip()]
        print(contexts)
    # TODO: run the model with different decoding methods and print the outputs (as outlined in the assignment)
    #Rows are temperature x k combinations (9 total rows),
    #columns are features, cells are filled with checks if the feature is present.
    lm = LanguageModel(mode='greedy')
    print(len(contexts))

    #temperatures = [0.2, 0.4, 0.6, 0.8, 1]
    #top_ks = [10, 20, 40, 60, 100]
    temperatures = [0.4, 0.6, 0.8]
    top_ks = [10, 20, 40]
    results = []

    print("top k decoding")
    n = 1
    for temperature in temperatures:
      print(f"Temperature: {temperature}")
      for top_k in top_ks:
        #top_k = 40
        lm = LanguageModel(mode='top-k', k=top_k) #, temperature=temperature)
        #all = []
        print(f"Top-k: {top_k}")
        for begining in contexts[:10]:
          output = lm.generate(begining, max_new_tokens=40)
          #all.append(output)
          print(f"{n}.  Context: {begining}\n→ {output}\n")
          n += 1
            #results.append({'temperature': temperature, 'top_k': top_k, 'outputs': all})
            #results.append(lm.generate(contexts[0]))
            #print(results)
            #print(lm.generate(contexts[0]))
# Out:
# ['Rick grew up in a troubled household.', "Laverne needs to prepare something for her friend's party.", 'Sarah had been dreaming of visiting Europe for years.', 'Gina was worried the cookie dough in the tube would be gross.', 'It was  my final performance in marching band.', 'Jim found an old disposable camera in the bottom of his junk drawer.', 'Ron started his new job as a landscaper today.', 'John and Billy became very skilled at beer pong.', 'Caroline was a student in medical school.', 'Trish hated the outdoors.', 'Tony was happy to be going on his first cruise.', 'Ignacio wants to play a sport while he is in college.', 'Danny bought a boat.', 'At school, Mary received an assignment to write an essay about pandas.', 'Ellen dreamed of winning a prize for her roses.', 'Jesse had just started fifth grade.', 'Tiffany was getting overwhelmed at work.', 'Gina misplaced her phone at her grandparents.', 'Alice was getting married in a few weeks.', 'Ted loves to go to the movies.', 'Nya had been asked on a paintball trip with friends.', "All of Javier's friends at school have smartphones.", 'Rachel decided to donate blood at the local blood drive.', 'Ron was watching a high-speed chase on TV.', 'Sam loved his old belt.', 'Larry bought a new motorcycle.', 'I went on a blind date a few days ago.', "Sammy's coffee grinder was broken.", 'Last week Jared was driving to work.', 'Joe grew a big batch of peas in his garden.', 'Aliza had a long lost ex-boyfriend she was bound to find.', 'Lina went to see how candy canes were made.', "When I first moved into my house, I didn't know my neighbors.", 'Bev had been studying very hard.', "We went to Frank Pepe's pizza shop three weeks ago.", 'Bernice always wanted to travel to Africa.', 'Jim made spinach cookies.', "Randy's friend gave him directions to his house.", 'I decided to go on a bike ride with my brother.', 'Anna went to the salon.', 'David and Sarah were friends during childhood.', 'AJ and his mom were at the grocery store.', 'Joe went to the junkyard to find treasures.', 'Priya decided to try a new restaurant.', 'Karen was assigned a roommate her first year of college.', 'We took a family vacation to the beach last year.', 'Donald was kind of the class clown.', "Eddie and Angela hadn't been talking to each other for a long time.", 'Rachel adopted a cat over ten Years ago.', 'Jim is a new driver and has never been pulled over before.', 'I love avocados.', 'David was an author that had trouble finding inspiration for his work.', 'Boris was addicted to video games.', 'A police officer came down with the flu today.', 'My friend nathan and his family went to the lake one summer.', 'Gary was a brave child.', 'Timmy was caught with unpaid parking tickets.', 'When I was younger, I went to summer camp.', 'Amber had a lot of things to do this Sunday.', 'Eve needed a new couch in her parlor.', 'Jason was terrified of spiders.', 'Linda began to have problems with a coworker at her job.', 'Sara wanted her kids to have a great Christmas.', 'Megan has been struggling with a drug habit for years.', 'Tyler has been unemployed for Years.', 'Bobby was having a birthday party.', 'It was the last day of our vacation.', 'Mother asked the children to help fold laundry.', 'Timmy loves watching cartoons.', 'My daughter had her baby shower in our Boston home.', "Pam's house was where the party was.", 'Ellen always hated school.', 'Jim got his first credit card in college.', 'Tim was entering a baking contest.', 'My two year old son refused to wear training pants.', 'Holly was glad to be safely inside her house as the storm raged.', 'Jill saw an infomercial for unbreakable glass cups.', 'Addie was working at the mall at Hollister when a strange man came in.', 'Sean was going for a job interview.', 'Fred made a bet with Sam over who could lose more weight in a month.', 'John went skydiving for the first time.', 'Gina and her family were leaving the park.', 'Kaya needed to buy a new dress for the upcoming Spring F ...
# 100
# top k decoding
# Temperature: 0.4
# Top-k: 10
# 1.  Context: Rick grew up in a troubled household.
# → Rick grew up in a troubled household. When his father died of cancer in the 1940s, his family went to a nearby boarding school to help him finish school, but his father was not interested in his studies. Instead of taking his brother
#
# 2.  Context: Laverne needs to prepare something for her friend's party.
# → Laverne needs to prepare something for her friend's party. It is the only thing he can do to get his daughter to go to school.
#
# "I'm so sorry. I was just doing my job. If you want to go to school I
#
# 3.  Context: Sarah had been dreaming of visiting Europe for years.
# → Sarah had been dreaming of visiting Europe for years. "When I got home and went to see her, I knew that I had to make a choice about her life."
#
# "I was very disappointed and I had to go for a walk in
#
# 4.  Context: Gina was worried the cookie dough in the tube would be gross.
# → Gina was worried the cookie dough in the tube would be gross. "I'm really not sure what I want to do with this, but I'm going to make this with a little more flour and I'll make it into a loaf," she said. "It
#
# 5.  Context: It was  my final performance in marching band.
# → It was  my final performance in marching band. I was in the same band, my friend in the same band, and I just wanted to be a leader. I wanted to be a good leader. I wanted a good group of people around me
#
# 6.  Context: Jim found an old disposable camera in the bottom of his junk drawer.
# → Jim found an old disposable camera in the bottom of his junk drawer. He took a couple photos with it and took a shot of the old lens, and then sent them to a friend who was going to send them to the police.
#
# He took the pictures to
#
# 7.  Context: Ron started his new job as a landscaper today.
# → Ron started his new job as a landscaper today. "The first thing he said to me was, 'You don't know what I'm doing,'" recalls her mother," she recalls. "I didn't think much about it at the time and he
#
# 8.  Context: John and Billy became very skilled at beer pong.
# → John and Billy became very skilled at beer pong. The guys who were on the team would come and play. And when Billy and I got to the bar, they'd go play the best they could. I had no idea that we would be in
#
# 9.  Context: Caroline was a student in medical school.
# → Caroline was a student in medical school.
#
# "I was just a little worried," she said. "I thought I was going to be out a lot of time and I was so excited."
#
# Caroline had to take the
#
# 10.  Context: Trish hated the outdoors.
# → Trish hated the outdoors. She loved to go out in the fields and play outside. She also loved to go hiking. She loved to play with kids. She loved to do something special for the people she knew.
#
#
#
# Top-k: 20
# 11.  Context: Rick grew up in a troubled household.
# → Rick grew up in a troubled household. It wasn't long before the man became increasingly abusive and aggressive, and he went to school alone. He was also known to have trouble sleeping, so when he left school, he went into a car
#
# 12.  Context: Laverne needs to prepare something for her friend's party.
# → Laverne needs to prepare something for her friend's party. And the party isn't going to be very interesting, either. He will just have to figure out how to make her feel better before he tries to kill her again. He needs to think about it
#
# 13.  Context: Sarah had been dreaming of visiting Europe for years.
# → Sarah had been dreaming of visiting Europe for years.
#
# She's been trying to get her father to come home to her. She says she's had three miscarriages and a miscarriage has taken hold.
#
# 'We were in touch for a
#
# 14.  Context: Gina was worried the cookie dough in the tube would be gross.
# → Gina was worried the cookie dough in the tube would be gross
# → Gina was worried the cookie dough in the tube would be gross. She asked for her daughter to take care of her sister.
#
# Somewhat embarrassed, the two decided not to return to the house while she and the boys sat by their computer.
#
#
#
# 85.  Context: It was  my final performance in marching band.
# → It was  my final performance in marching band. I thought I would play it in a few days at the end of the night. The band was still in high spirits going into the morning hours, especially in the rain and snow. They also brought
#
# 86.  Context: Jim found an old disposable camera in the bottom of his junk drawer.
# → Jim found an old disposable camera in the bottom of his junk drawer. For a $250 check, he'd bought 3 boxes of old-age DVDs, and had one of these ready to sell himself when he was supposed to be ready for another.
#
# "But
#
# 87.  Context: Ron started his new job as a landscaper today.
# → Ron started his new job as a landscaper today. While there, the only other thing he does is bring home all the fresh plants he grows. There isn't much of that as there is in the world, even with this type of landscaping.
#
# 88.  Context: John and Billy became very skilled at beer pong.
# → John and Billy became very skilled at beer pong. When they reached the end of their partnership he would play a game with the boys and Billy would drink all the beer while the team competed for their place on the National Hockey League. When all is said
#
# 89.  Context: Caroline was a student in medical school.
# → Caroline was a student in medical school. When she was 21, she enrolled and went on to graduate school at UC Berkeley and have a doctorate in pharmacology. She became the first woman to receive a doctorate, and her experience in
#
# 90.  Context: Trish hated the outdoors.
# → Trish hated the outdoors. She was a former tennis player and a long-distance runner. "She told me it wasn't as easy to fly or run," she says. "At home, people who don't have a

# %% [markdown]
# #Identify ~3-5 features on which to evaluate results qualitatively. Explain why you chose these.
#
#
#
#
# ---
#
#
# It depens on wht you want to do. Right now I just want it to be: cohesive with the prompt, the refrenced gender to be consistent, and for (what I view) as a smooth sentence. This would allow me to think that it coul dhave been a sentence someone actually said in real life.

# %% [markdown]
# 0.4, 10 (maybe 40) : this one is more cohesive, smooth telling, and has gender consistent
# 0.2, 10
#
#
#
# 0.6 20 <- temp 0.6 is pretty good in general

# %%
import pandas as pd

temperatures = [0.4, 0.6, 0.8]
ks = [10, 20, 40]
features = ["Coherence", "Consistency", "Smoothness"]
results = [["✓","X","✓"],
           ["X","X","✓"],
           ["✓","X","X"],

           ["X","✓","✓"],
           ["✓","✓","X"],
           ["✓","✓","✓"],

            ["✓","✓","✓"],
           ["✓","✓","X"],
           ["X","✓","✓"]]

rows = []
# Initialize an index to track which set of results corresponds to the current (temperature, k) combination
results_row_index = 0

for t in temperatures:
    for k in ks:
        row = {"temperature": t, "k": k}
        # Iterate through features with their index and name
        for feature_col_index, feature_name in enumerate(features):
            if results_row_index < len(results):
                # Access the specific feature result from the 'results' list
                # Use feature_name as the dictionary key and feature_col_index to get the value
                row[feature_name] = results[results_row_index][feature_col_index]
        rows.append(row)
        results_row_index += 1 # Move to the next set of results for the next combination

df = pd.DataFrame(rows)
print(df)
# Out:
#    temperature   k Coherence Consistency Smoothness
# 0          0.4  10         ✓           X          ✓
# 1          0.4  20         X           X          ✓
# 2          0.4  40         ✓           X          X
# 3          0.6  10         X           ✓          ✓
# 4          0.6  20         ✓           ✓          X
# 5          0.6  40         ✓           ✓          ✓
# 6          0.8  10         ✓           ✓          ✓
# 7          0.8  20         ✓           ✓          X
# 8          0.8  40         X           ✓          ✓
